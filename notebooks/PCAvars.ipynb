# %% [markdown]
# ## Use PCA to determine the most important features
#
# The vector of most importance will be used to determine the relative importance of the indiviudal features.

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
df = pd.read_csv('../data/processed_data.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1       1   27     Software Engineer             6.1
# 1            2       1   28                Doctor             6.2
# 2            3       1   28                Doctor             6.2
# 3            4       1   28  Sales Representative             5.9
# 4            5       1   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370       0   59                 Nurse             8.1
# 370        371       0   59                 Nurse             8.0
# 371        372       0   59                 Nurse             8.1
# 372        373       0   59                 Nurse             8.1
# 373        374       0   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level  BMI Category  \
# 0                   6                       42             6             2
# 1                   6                       60             8             1
# 2                   6                       60             8             1
# 3                   4                       30             8             3
# 4                   4                       30             8             3
# ..                ...                      ...           ...           ...
# 369                 9                       75             3             2
# 370                 9                       75             3             2
# 371                 9                       75             3             2
# 372                 9                       75             3             2
# 373                 9                       75             3             2
#
#     Blood Pressure  Heart Rate  Daily Steps  Sleep Disorder  \
# 0           126/83          77         4200               0
# 1           125/80          75        10000               0
# 2           125/80          75        10000               0
# 3           140/90          85         3000               1
# 4           140/90          85         3000               1
# ..             ...         ...          ...             ...
# 369         140/95          68         7000               1
# 370         140/95          68         7000               1
# 371         140/95          68         7000               1
# 372         140/95          68         7000               1
# 373         140/95          68         7000               1
#
#      Systolic Pressure  Diastolic Pressure
# 0                  126                  83
# 1                  125                  80
# 2                  125                  80
# 3                  140                  90
# 4                  140                  90
# ..                 ...                 ...
# 369                140                  95
# 370                140                  95
# 371                140                  95
# 372                140                  95
# 373                140                  95
#
# [374 rows x 15 columns]

# %%
selected_cols = ['Gender', 'Age', 'Sleep Duration', 
                 'Physical Activity Level', 
                 'Stress Level','BMI Category', 
                 'Heart Rate', 'Daily Steps','Sleep Disorder', 
                 'Systolic Pressure', 'Diastolic Pressure']

# selected_cols = ['Gender', 'Age', 'Sleep Duration', 
#                  'Stress Level', 'BMI Category', 'Heart Rate', 'Sleep Disorder']

X = df[selected_cols]

scaler = StandardScaler()
data_scaled = scaler.fit_transform(X)

pca = PCA(n_components=len(selected_cols))
pca.fit(data_scaled)

important_vec = pca.components_[0]
ranking = np.argsort(important_vec)

sq_sum = 0
for i in ranking:
    sq_sum += important_vec[i]**2
    print(f"{selected_cols[i]}:               {important_vec[i]}")

print(sq_sum)
# Out:
# Gender:               -0.1607491093558937
# Sleep Duration:               -0.15798220947097708
# Daily Steps:               0.08432512777764747
# Stress Level:               0.1043614858646622
# Physical Activity Level:               0.1506074924721753
# Heart Rate:               0.20686642761030252
# Age:               0.29363653811869483
# BMI Category:               0.41267114905408464
# Sleep Disorder:               0.41850806064455515
# Systolic Pressure:               0.462623752869336
# Diastolic Pressure:               0.469077110335847
# 0.9999999999999999
